# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv("titanic_train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 1]There is missing data in Age and cabin, so i will fill the age value with mean.

# %%
df["Age"]=df["Age"].fillna((df["Age"].median()))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [raw]
# Above we can see the passenger ages range from 0.4 to 80,in the above contain missing value in ages,the mean is higher than standard
# deviation skweness is present.

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Sex']=le.fit_transform (df["Sex"])
df['Sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int32

# %% [raw]
# sex for 0 is male and 1 for female to identify the Gender

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
# ...

# %%
df.drop(["SibSp","Cabin"],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
# ...

# %% [raw]
# Data cleasing has done now Eda process start

# %% [markdown]
# # EDA

# %%
df.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # Multivarate Analysis

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr=df.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %% [raw]
# 1]very high correlation between survived and sex
# 2]pclass is negatively corelated
# 3]we will drop pclass

# %%
df.drop("Pclass",axis=1,inplace=True)

# %%
df
# Out:
#      Survived                                               Name  Sex   Age  \
# 0           0                            Braund, Mr. Owen Harris    1  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2           1                             Heikkinen, Miss. Laina    0  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4           0                           Allen, Mr. William Henry    1  35.0
# ..        ...                                                ...  ...   ...
# 886         0                              Montvila, Rev. Juozas    1  27.0
# 887         1                       Graham, Miss. Margaret Edith    0  19.0
# 888         0           Johnston, Miss. Catherine Helen "Carrie"    0  28.0
# 889         1                              Behr, Mr. Karl Howell    1  26.0
# 890         0                                Dooley, Mr. Patrick    1  32.0
#
#      Parch            Ticket     Fare Embarked
# ...

# %% [markdown]
# # handaling outlier

# %%
collist=df.columns.values
collist=8
nrows=12

# %%
df.plot(kind='box',subplots=True,layout=(2,4))
# Out:
# Survived       AxesSubplot(0.125,0.536818;0.168478x0.343182)
# Sex         AxesSubplot(0.327174,0.536818;0.168478x0.343182)
# Age         AxesSubplot(0.529348,0.536818;0.168478x0.343182)
# Parch       AxesSubplot(0.731522,0.536818;0.168478x0.343182)
# Fare              AxesSubplot(0.125,0.125;0.168478x0.343182)
# dtype: object

# %% [raw]
# outlier are present in ages,fare and Parch

# %% [markdown]
# # checking the distribution  of skewness

# %%
sns.distplot(df['Age'])

# %%
sns.distplot(df['Parch'])

# %%
sns.distplot(df['Fare'])

# %% [raw]
# skwness is present in Fare and Parch,ages,we will drop Fare and parch

# %%
df.drop('Parch',axis=1,inplace=True)

# %%
df.drop('Fare',axis=1,inplace=True)

# %%
df
# Out:
#      Survived                                               Name  Sex   Age  \
# 0           0                            Braund, Mr. Owen Harris    1  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2           1                             Heikkinen, Miss. Laina    0  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4           0                           Allen, Mr. William Henry    1  35.0
# ..        ...                                                ...  ...   ...
# 886         0                              Montvila, Rev. Juozas    1  27.0
# 887         1                       Graham, Miss. Margaret Edith    0  19.0
# 888         0           Johnston, Miss. Catherine Helen "Carrie"    0  28.0
# 889         1                              Behr, Mr. Karl Howell    1  26.0
# 890         0                                Dooley, Mr. Patrick    1  32.0
#
#                Ticket Embarked
# ...

# %%
df.drop('Embarked',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    int32
#  3   Age       891 non-null    float64
#  4   Ticket    891 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(2)
# memory usage: 24.4+ KB

# %%
df.drop(['Ticket','Name'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Sex   Age
# 0           0    1  22.0
# 1           1    0  38.0
# 2           1    0  26.0
# 3           1    0  35.0
# 4           0    1  35.0
# ..        ...  ...   ...
# 886         0    1  27.0
# 887         1    0  19.0
# 888         0    0  28.0
# 889         1    1  26.0
# 890         0    1  32.0
#
# [891 rows x 3 columns]

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
new_df=df[(z<3).all(axis=1)]

# %%
print('original shape=',df.shape,'\nnew shape=',new_df.shape)
# Out:
# original shape= (891, 3)
# new shape= (884, 3)

# %% [raw]
# 7 outliers has removed from dataset

# %%
new_df.skew()
# Out:
# Survived    0.470232
# Sex        -0.606144
# Age         0.334219
# dtype: float64

# %% [raw]
# sex has positive relation with target variable so it is acceptable

# %% [markdown]
# # Preparing Model for training has we will use Logistic Regression for this dataset

# %%
new_df
# Out:
#      Survived  Sex   Age
# 0           0    1  22.0
# 1           1    0  38.0
# 2           1    0  26.0
# 3           1    0  35.0
# 4           0    1  35.0
# ..        ...  ...   ...
# 886         0    1  27.0
# 887         1    0  19.0
# 888         0    0  28.0
# 889         1    1  26.0
# 890         0    1  32.0
#
# [884 rows x 3 columns]

# %%
x=new_df.drop('Age',axis=1)
y=new_df['Age']

# %%
x
# Out:
#      Survived  Sex
# 0           0    1
# 1           1    0
# 2           1    0
# 3           1    0
# 4           0    1
# ..        ...  ...
# 886         0    1
# 887         1    0
# 888         0    0
# 889         1    1
# 890         0    1
#
# [884 rows x 2 columns]

# %%
y
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 884, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
sc=StandardScaler()
scaledx=sc.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-2d6b701fc09e> in <module>
# ----> 1 sc=StandardScaler()
#       2 scaledx=sc.fit_transform(x)
#
# NameError: name 'StandardScaler' is not defined

# %%
best_rstate=0
accu=0
for i in range(80,800):
    x_train,x_test,y_train,y_test=train_test_split(scaledx,y,test_size=.30,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    predmod=mod.predict(x_test)
    tempaccu=r2_score(y_test,predmod)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
print(f" best accuarcy {accu*6000} found on random_state {best_rstate}")

# %% [markdown]
# we found best random_state is 779,we will be using train_test_split in next step

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaledx,y,test_size=.30,random_state=779)

# %% [markdown]
# # Finding the best model

# %% [markdown]
# LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
r2score=r2_score(y_test,predlr)
cvscore=cross_val_score(LinearRegression(),x_train,y_train,cv=2).mean()
print(f" accuracy={r2score*6000},cross_val_score={cvscore*6000} & difference={(r2score*6000)-(cvscore*6000)}")

# %% [markdown]
# RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
r2score=r2_score(y_test,predlr)
cvscore=cross_val_score(RandomForestRegressor(),x_train,y_train,cv=2).mean()
print(f" accuracy={r2score*6000},cross_val_score={cvscore*6000} & difference={(r2score*6000)-(cvscore*6000)}")

# %% [markdown]
# AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
r2score=r2_score(y_test,predad)
cvscore=cross_val_score(AdaBoostRegressor(),x_train,y_train,cv=2).mean()
print(f" accuracy={r2score*6000},cross_val_score={cvscore*6000} & difference={(r2score*6000)-(cvscore*6000)}")

# %% [markdown]
# SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
predsgd=sgd.predict(x_test)
r2score=r2_score(y_test,predsgd)
cvscore=cross_val_score(SGDRegressor(),x_train,y_train,cv=2).mean()
print(f" accuracy={r2score*6000},cross_val_score={cvscore*6000} & difference={(r2score*6000)-(cvscore*6000)}")

# %% [markdown]
# AdaboostRegressor is best performing model,with the high accuracy,so i am moving AdaBoostRegressor

# %% [markdown]
# # model saving

# %%
import pickle
filename="titanic_train.ipynb"
pickle.dump(ad,open(filename,"wb"))

# %% [markdown]
# # conclusion:

# %%
import numpy as np
a=np.array(y_test)
